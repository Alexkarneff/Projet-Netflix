# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('../data/dataset/credits.csv')
df2 = pd.read_csv('../data/dataset/movies_metadata.csv')

# %%
df2.head(10)

# %%
df2[df2["budget"]=="0"]

# %%
df2.isnull().sum()

# %%
df1.isnull().sum()
